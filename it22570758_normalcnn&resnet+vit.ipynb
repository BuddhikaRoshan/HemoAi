# %% [markdown]
# <a href="https://colab.research.google.com/github/BuddhikaRoshan/HemoAi/blob/Heshani/it22570758_normalcnn%26resnet%2Bvit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pickle
import matplotlib.pyplot as plt


import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# ==========================================
# SETTINGS
# ==========================================
IMG_SIZE = 64
BATCH_SIZE = 8
EPOCHS = 40
SELECTED_SHAPES = 5

TARGET_SHAPE_COUNT = 200
TARGET_THAL_COUNT = 800

shape_dir = "/content/drive/MyDrive/thalassemia_shape_based/dataset/shapes"
disease_dir = "/content/drive/MyDrive/thalassemia_shape_based/dataset/disease"

# %%
def preprocess_image(path):
    img = cv2.imread(path)
    if img is None:
        return None

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Contrast enhancement
    lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    l = cv2.equalizeHist(l)
    lab = cv2.merge((l, a, b))
    img = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img = img / 255.0
    return img

# %%
augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

def augment_image_array(img):
    img = tf.expand_dims(img, 0)
    img = augment(img)
    return img[0].numpy()

# %%
def load_shape_data_balanced(folder):
    images, labels = [], []
    classes = sorted(os.listdir(folder))

    for idx, cls in enumerate(classes):
        path = os.path.join(folder, cls)
        if not os.path.isdir(path):
            continue

        files = [f for f in os.listdir(path)
                 if f.lower().endswith(('.png','.jpg','.jpeg','.bmp','.tif'))]

        class_imgs = []

        for file in files:
            img = preprocess_image(os.path.join(path, file))
            if img is not None:
                class_imgs.append(img)

        if len(class_imgs) == 0:
            continue

        # original images
        for img in class_imgs:
            images.append(img)
            labels.append(idx)

        # augmentation to balance
        current = len(class_imgs)
        i = 0
        while current < TARGET_SHAPE_COUNT:
            img = class_imgs[i % len(class_imgs)]
            images.append(augment_image_array(img))
            labels.append(idx)
            current += 1
            i += 1

        print(f"{cls}: {current}")

    return np.array(images), np.array(labels), classes

# %%
from tensorflow.keras import layers, models
import tensorflow as tf

def build_mobilenet_vit_model(num_classes):

    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = augment(inputs)

    # -------------------------
    # CNN Backbone (MobileNet)
    # -------------------------
    base = tf.keras.applications.MobileNetV2(
        include_top=False,
        weights="imagenet",
        input_tensor=x
    )

    # Freeze most layers
    for layer in base.layers[:-30]:
        layer.trainable = False

    x = base.output   # shape: (None, H, W, C)

    # -------------------------
    # Convert CNN feature map → patches (for ViT)
    # -------------------------
    h, w, c = x.shape[1], x.shape[2], x.shape[3]
    num_patches = h * w

    x = layers.Reshape((num_patches, c))(x)

    # Linear projection
    projection_dim = 64
    x = layers.Dense(projection_dim)(x)

    # -------------------------
    # Transformer Block (ViT)
    # -------------------------
    num_heads = 4
    transformer_units = 128

    # LayerNorm
    x1 = layers.LayerNormalization(epsilon=1e-6)(x)

    # Multi-head attention
    attention_output = layers.MultiHeadAttention(
        num_heads=num_heads,
        key_dim=projection_dim
    )(x1, x1)

    # Skip connection
    x2 = layers.Add()([attention_output, x])

    # Feed-forward network
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
    x3 = layers.Dense(transformer_units, activation="relu")(x3)
    x3 = layers.Dense(projection_dim)(x3)

    x = layers.Add()([x3, x2])

    # -------------------------
    # Classification Head
    # -------------------------
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.4)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-4),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(
    "best_shape_model.keras",
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# %%
# Ensure shape_classes is defined by loading the data first.
# We only need the classes for building the model in this step.
# X_shapes and y_shapes will be reloaded and properly split in a subsequent cell (s2kObOsT7oN5) for training.
X_dummy, y_dummy, shape_classes = load_shape_data_balanced(shape_dir)
shape_model = build_mobilenet_vit_model(len(shape_classes))
# Out:
# acantocyte: 354
# elliptocyte: 1213
# hypochromic: 225
# normal: 1431
# pencil: 200
# sperobulat: 562
# stomatocyte: 382
# target: 851
# teardrop: 2077
# /tmp/ipykernel_457/3592425324.py:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base = tf.keras.applications.MobileNetV2(

# %%
# Assuming IMG_SIZE is now 96, and shape_dir is defined.
# Need to reload data because IMG_SIZE was changed from 128 to 96.
print("Reloading shape dataset with updated IMG_SIZE...")
X_shapes, y_shapes, shape_classes = load_shape_data_balanced(shape_dir)

# Convert labels to categorical
y_shapes_cat = tf.keras.utils.to_categorical(y_shapes, len(shape_classes))

# Rebuild the shape model to ensure its input layer matches the new IMG_SIZE
# and number of classes. `build_mobilenet_vit_model` uses the global IMG_SIZE.
shape_model = build_mobilenet_vit_model(len(shape_classes))

# Split data again with the new X_shapes and y_shapes_cat
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X_shapes,
    y_shapes_cat,
    test_size=0.2,
    stratify=y_shapes,   # VERY IMPORTANT
    random_state=42
)

history = shape_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop, reduce_lr, checkpoint],
    verbose=1
)
# Out:
# Reloading shape dataset with updated IMG_SIZE...
# acantocyte: 354
# elliptocyte: 1213
# hypochromic: 225
# normal: 1431
# pencil: 200
# sperobulat: 562
# stomatocyte: 382
# target: 851
# teardrop: 2077
# /tmp/ipykernel_457/3592425324.py:12: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base = tf.keras.applications.MobileNetV2(
# Epoch 1/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.4614 - loss: 1.5986
# Epoch 1: val_accuracy improved from -inf to 0.78410, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 106s 116ms/step - accuracy: 0.4616 - loss: 1.5981 - val_accuracy: 0.7841 - val_loss: 0.6738 - learning_rate: 1.0000e-04
# Epoch 2/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7657 - loss: 0.7668
# Epoch 2: val_accuracy improved from 0.78410 to 0.86223, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 137s 109ms/step - accuracy: 0.7657 - loss: 0.7668 - val_accuracy: 0.8622 - val_loss: 0.3970 - learning_rate: 1.0000e-04
# Epoch 3/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8139 - loss: 0.6230
# Epoch 3: val_accuracy improved from 0.86223 to 0.87252, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 82s 113ms/step - accuracy: 0.8139 - loss: 0.6230 - val_accuracy: 0.8725 - val_loss: 0.4234 - learning_rate: 1.0000e-04
# Epoch 4/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8120 - loss: 0.6009
# Epoch 4: val_accuracy did not improve from 0.87252
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 109ms/step - accuracy: 0.8121 - loss: 0.6009 - val_accuracy: 0.8451 - val_loss: 0.4516 - learning_rate: 1.0000e-04
# Epoch 5/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8355 - loss: 0.4919
# Epoch 5: val_accuracy improved from 0.87252 to 0.88280, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 110ms/step - accuracy: 0.8355 - loss: 0.4919 - val_accuracy: 0.8828 - val_loss: 0.3650 - learning_rate: 1.0000e-04
# Epoch 6/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8471 - loss: 0.4840
# Epoch 6: val_accuracy did not improve from 0.88280
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 79s 109ms/step - accuracy: 0.8471 - loss: 0.4840 - val_accuracy: 0.8156 - val_loss: 0.4723 - learning_rate: 1.0000e-04
# Epoch 7/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8500 - loss: 0.4721
# Epoch 7: val_accuracy did not improve from 0.88280
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 79s 108ms/step - accuracy: 0.8500 - loss: 0.4721 - val_accuracy: 0.8143 - val_loss: 0.5206 - learning_rate: 1.0000e-04
# Epoch 8/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8557 - loss: 0.4446
# Epoch 8: val_accuracy improved from 0.88280 to 0.89102, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 85s 116ms/step - accuracy: 0.8557 - loss: 0.4446 - val_accuracy: 0.8910 - val_loss: 0.3256 - learning_rate: 1.0000e-04
# Epoch 9/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8628 - loss: 0.4223
# Epoch 9: val_accuracy did not improve from 0.89102
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 110ms/step - accuracy: 0.8629 - loss: 0.4223 - val_accuracy: 0.8588 - val_loss: 0.4028 - learning_rate: 1.0000e-04
# Epoch 10/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8775 - loss: 0.3717
# Epoch 10: val_accuracy did not improve from 0.89102
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 86s 116ms/step - accuracy: 0.8775 - loss: 0.3717 - val_accuracy: 0.8746 - val_loss: 0.3456 - learning_rate: 1.0000e-04
# Epoch 11/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8833 - loss: 0.3628
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 11: val_accuracy did not improve from 0.89102
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 109ms/step - accuracy: 0.8833 - loss: 0.3629 - val_accuracy: 0.8828 - val_loss: 0.3538 - learning_rate: 1.0000e-04
# Epoch 12/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8934 - loss: 0.3314
# Epoch 12: val_accuracy improved from 0.89102 to 0.91570, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 110ms/step - accuracy: 0.8934 - loss: 0.3314 - val_accuracy: 0.9157 - val_loss: 0.2424 - learning_rate: 3.0000e-05
# Epoch 13/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8913 - loss: 0.3431
# Epoch 13: val_accuracy did not improve from 0.91570
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 109ms/step - accuracy: 0.8913 - loss: 0.3431 - val_accuracy: 0.9109 - val_loss: 0.2552 - learning_rate: 3.0000e-05
# Epoch 14/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9026 - loss: 0.3139
# Epoch 14: val_accuracy improved from 0.91570 to 0.92049, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 82s 113ms/step - accuracy: 0.9026 - loss: 0.3139 - val_accuracy: 0.9205 - val_loss: 0.2307 - learning_rate: 3.0000e-05
# Epoch 15/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9091 - loss: 0.2895
# Epoch 15: val_accuracy did not improve from 0.92049
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 139s 109ms/step - accuracy: 0.9091 - loss: 0.2895 - val_accuracy: 0.9068 - val_loss: 0.2565 - learning_rate: 3.0000e-05
# Epoch 16/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8908 - loss: 0.3248
# Epoch 16: val_accuracy did not improve from 0.92049
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 82s 109ms/step - accuracy: 0.8908 - loss: 0.3248 - val_accuracy: 0.9191 - val_loss: 0.2350 - learning_rate: 3.0000e-05
# Epoch 17/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9035 - loss: 0.2932
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 17: val_accuracy did not improve from 0.92049
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 109ms/step - accuracy: 0.9035 - loss: 0.2932 - val_accuracy: 0.9164 - val_loss: 0.2461 - learning_rate: 3.0000e-05
# Epoch 18/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9133 - loss: 0.2624
# Epoch 18: val_accuracy improved from 0.92049 to 0.92186, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 110ms/step - accuracy: 0.9133 - loss: 0.2624 - val_accuracy: 0.9219 - val_loss: 0.2282 - learning_rate: 9.0000e-06
# Epoch 19/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9179 - loss: 0.2660
# Epoch 19: val_accuracy did not improve from 0.92186
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 84s 115ms/step - accuracy: 0.9179 - loss: 0.2660 - val_accuracy: 0.9219 - val_loss: 0.2257 - learning_rate: 9.0000e-06
# Epoch 20/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9138 - loss: 0.2829
# Epoch 20: val_accuracy improved from 0.92186 to 0.92735, saving model to best_shape_model.keras
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 110ms/step - accuracy: 0.9138 - loss: 0.2829 - val_accuracy: 0.9273 - val_loss: 0.2166 - learning_rate: 9.0000e-06
# Epoch 21/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9122 - loss: 0.2740
# Epoch 21: val_accuracy did not improve from 0.92735
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 110ms/step - accuracy: 0.9122 - loss: 0.2739 - val_accuracy: 0.9253 - val_loss: 0.2287 - learning_rate: 9.0000e-06
# Epoch 22/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9135 - loss: 0.2651
# Epoch 22: val_accuracy did not improve from 0.92735
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 83s 111ms/step - accuracy: 0.9135 - loss: 0.2651 - val_accuracy: 0.9184 - val_loss: 0.2258 - learning_rate: 9.0000e-06
# Epoch 23/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9186 - loss: 0.2426
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 23: val_accuracy did not improve from 0.92735
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 80s 109ms/step - accuracy: 0.9186 - loss: 0.2426 - val_accuracy: 0.9267 - val_loss: 0.2230 - learning_rate: 9.0000e-06
# Epoch 24/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9193 - loss: 0.2484
# Epoch 24: val_accuracy did not improve from 0.92735
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 79s 109ms/step - accuracy: 0.9193 - loss: 0.2484 - val_accuracy: 0.9260 - val_loss: 0.2223 - learning_rate: 2.7000e-06
# Epoch 25/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9195 - loss: 0.2569
# Epoch 25: val_accuracy did not improve from 0.92735
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 79s 109ms/step - accuracy: 0.9195 - loss: 0.2569 - val_accuracy: 0.9267 - val_loss: 0.2224 - learning_rate: 2.7000e-06
# Epoch 26/40
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9185 - loss: 0.2591
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 26: val_accuracy did not improve from 0.92735
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 79s 108ms/step - accuracy: 0.9185 - loss: 0.2591 - val_accuracy: 0.9253 - val_loss: 0.2230 - learning_rate: 2.7000e-06

# %%
epochs_range = range(1, len(history.history['accuracy']) + 1)

plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(epochs_range, history.history['accuracy'], marker='o')
plt.plot(epochs_range, history.history['val_accuracy'], marker='o')
plt.title("Shape Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.grid(True)

# Loss
plt.subplot(1,2,2)
plt.plot(epochs_range, history.history['loss'], marker='o')
plt.plot(epochs_range, history.history['val_loss'], marker='o')
plt.title("Shape Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.grid(True)

plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd
import numpy as np

# Predict on validation/test set
y_pred = np.argmax(shape_model.predict(X_val), axis=1)
y_true = np.argmax(y_val, axis=1)

# ===== Print Test Accuracy (like your screenshot) =====
test_acc = accuracy_score(y_true, y_pred)
print("TEST ACCURACY:", test_acc)

# ===== Classification report as table =====
report_dict = classification_report(
    y_true,
    y_pred,
    target_names=shape_classes,
    output_dict=True
)

report_df = pd.DataFrame(report_dict).transpose()
report_df
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step
# TEST ACCURACY: 0.9273474982864977
#               precision    recall  f1-score      support
# acantocyte     0.971831  0.971831  0.971831    71.000000
# elliptocyte    0.884774  0.884774  0.884774   243.000000
# hypochromic    0.857143  0.666667  0.750000    45.000000
# normal         0.882736  0.947552  0.913997   286.000000
# pencil         0.948718  0.925000  0.936709    40.000000
# sperobulat     0.973214  0.973214  0.973214   112.000000
# stomatocyte    0.746479  0.688312  0.716216    77.000000
# target         0.934911  0.929412  0.932153   170.000000
# teardrop       0.997573  0.990361  0.993954   415.000000
# accuracy       0.927347  0.927347  0.927347     0.927347
# macro avg      0.910820  0.886347  0.896983  1459.000000
# weighted avg   0.926929  0.927347  0.926475  1459.000000

# %%
shape_model.save("shape_model.keras")
print("Shape model saved")
# Out:
# Shape model saved

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
IMG_SIZE = 96
BATCH_SIZE = 8
EPOCHS = 20

# %%
shape_model = tf.keras.models.load_model("/content/shape_model.keras")

# %%
def preprocess_image(path):

    img = cv2.imread(path)

    if img is None:
        return None

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    l,a,b = cv2.split(lab)

    l = cv2.equalizeHist(l)

    lab = cv2.merge((l,a,b))
    img = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

    img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))

    img = img / 255.0

    return img

# %%
def get_shape_percentage(img):

    img_small = cv2.resize(img,(64,64))
    img_small = np.expand_dims(img_small,0)

    probs = shape_model.predict(img_small,verbose=0)[0]

    return probs

# %%
def blue_gradient(img):

    blue = np.mean(img[:,:,2])

    return blue

# %%
def extract_shape_and_blue_features(img):

    shape = get_shape_percentage(img)

    blue = blue_gradient(img)

    features = np.concatenate([shape,[blue]])

    return features

# %%
import os

dataset_path = "/content/drive/MyDrive/thalassemia_shape_based/dataset/disease"

image_paths = []
labels = []

for class_name in os.listdir(dataset_path):

    class_folder = os.path.join(dataset_path, class_name)

    if not os.path.isdir(class_folder):
        continue

    # assign label
    if class_name.lower() == "healthy":
        label = 0
    elif class_name.lower() == "thalassemia":
        label = 1
    else:
        continue

    for root, dirs, files in os.walk(class_folder):

        for file in files:

            if file.lower().endswith((".jpg",".jpeg",".png",".tif",".tiff")):

                full_path = os.path.join(root, file)

                image_paths.append(full_path)
                labels.append(label)

print("Total Images:", len(image_paths))
print("Healthy Images:", labels.count(0))
print("Thalassemia Images:", labels.count(1))
# Out:
# Total Images: 991
# Healthy Images: 800
# Thalassemia Images: 191

# %%
images = []
extra_features = []

for path in image_paths:

    img = preprocess_image(path)

    images.append(img)

    feature = extract_shape_and_blue_features(img)

    extra_features.append(feature)


images = np.array(images)
extra_features = np.array(extra_features)
labels = np.array(labels)

print("Images shape:",images.shape)
print("Features shape:",extra_features.shape)
# Out:
# Images shape: (991, 96, 96, 3)
# Features shape: (991, 10)

# %%
from sklearn.model_selection import train_test_split

X_train_img, X_test_img, X_train_feat, X_test_feat, y_train, y_test = train_test_split(
    images,
    extra_features,
    labels,
    test_size=0.2,
    random_state=42,
    stratify=labels
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=25,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8,1.2]
)

datagen.fit(X_train_img)

# %%
history = model.fit(

    [X_train_img, X_train_feat],
    y_train,

    validation_data=([X_test_img,X_test_feat],y_test),

    epochs=20,
    batch_size=16
)
# Out:
# Epoch 1/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - accuracy: 0.9840 - loss: 0.0748 - val_accuracy: 0.9648 - val_loss: 0.1258
# Epoch 2/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9947 - loss: 0.0132 - val_accuracy: 0.9799 - val_loss: 0.0675
# Epoch 3/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 183ms/step - accuracy: 0.9826 - loss: 0.0522 - val_accuracy: 0.9196 - val_loss: 0.2601
# Epoch 4/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 0.9924 - loss: 0.0262 - val_accuracy: 0.9246 - val_loss: 0.1653
# Epoch 5/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9903 - loss: 0.0351 - val_accuracy: 0.9899 - val_loss: 0.0120
# Epoch 6/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.9942 - loss: 0.0254 - val_accuracy: 0.9849 - val_loss: 0.0383
# Epoch 7/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 225ms/step - accuracy: 0.9897 - loss: 0.0270 - val_accuracy: 0.9698 - val_loss: 0.0845
# Epoch 8/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - accuracy: 0.9976 - loss: 0.0220 - val_accuracy: 0.9548 - val_loss: 0.1366
# Epoch 9/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9921 - loss: 0.0172 - val_accuracy: 0.9497 - val_loss: 0.1745
# Epoch 10/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step - accuracy: 0.9962 - loss: 0.0121 - val_accuracy: 0.9899 - val_loss: 0.0177
# Epoch 11/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 178ms/step - accuracy: 0.9905 - loss: 0.0323 - val_accuracy: 0.9799 - val_loss: 0.0297
# Epoch 12/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9949 - loss: 0.0162 - val_accuracy: 0.9749 - val_loss: 0.0668
# Epoch 13/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9908 - loss: 0.0398 - val_accuracy: 0.9648 - val_loss: 0.0862
# Epoch 14/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9941 - loss: 0.0222 - val_accuracy: 0.9950 - val_loss: 0.0108
# Epoch 15/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.9938 - loss: 0.0197 - val_accuracy: 0.9899 - val_loss: 0.0443
# Epoch 16/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 211ms/step - accuracy: 0.9965 - loss: 0.0137 - val_accuracy: 0.9849 - val_loss: 0.0349
# Epoch 17/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9905 - loss: 0.0190 - val_accuracy: 0.9749 - val_loss: 0.1036
# Epoch 18/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - accuracy: 0.9978 - loss: 0.0134 - val_accuracy: 0.9648 - val_loss: 0.1354
# Epoch 19/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 0.9910 - loss: 0.0148 - val_accuracy: 0.9598 - val_loss: 0.2011
# Epoch 20/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 183ms/step - accuracy: 0.9934 - loss: 0.0259 - val_accuracy: 0.9548 - val_loss: 0.1943

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model Accuracy")
plt.legend(["Train","Validation"])
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model Loss")
plt.legend(["Train","Validation"])
plt.show()

# %%
y_pred = np.argmax(model.predict([X_test_img, X_test_feat]), axis=1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

results_table = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1 Score"],
    "Score": [accuracy, precision, recall, f1]
})

print(results_table)
# Out:
#       Metric     Score
# 0   Accuracy  0.954774
# 1  Precision  1.000000
# 2     Recall  0.763158
# 3   F1 Score  0.865672

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

def make_gradcam_heatmap(img_array, model, last_conv_layer_name):

    grad_model = tf.keras.models.Model(
        [model.inputs],
        [model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:

        conv_outputs, predictions = grad_model(img_array)
        class_channel = predictions[:, tf.argmax(predictions[0])]

    grads = tape.gradient(class_channel, conv_outputs)

    pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))

    conv_outputs = conv_outputs[0]

    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]

    heatmap = tf.squeeze(heatmap)

    heatmap = np.maximum(heatmap,0) / np.max(heatmap)

    return heatmap

# %%
# Save full hybrid model
model.save("thalassemia_hybrid_model.keras")

# Save also in H5 format
model.save("thalassemia_hybrid_model.h5")

print("Model saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!

# %%
model.save("/content/drive/MyDrive/thalassemia_hybrid_model1.keras")
model.save("/content/drive/MyDrive/thalassemia_hybrid_model1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import cv2
import numpy as np
import tensorflow as tf

IMG_SIZE = 96

# load models
model = tf.keras.models.load_model("/content/drive/MyDrive/thalassemia_hybrid_model1.keras")
shape_model = tf.keras.models.load_model("shape_model.keras")


# -----------------------------
# Image preprocessing
# -----------------------------
def preprocess_image(path):

    img = cv2.imread(path)

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    l,a,b = cv2.split(lab)

    l = cv2.equalizeHist(l)

    lab = cv2.merge((l,a,b))
    img = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

    img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))

    img = img / 255.0

    return img


# -----------------------------
# Shape percentage
# -----------------------------
def get_shape_percentage(img):

    img_small = cv2.resize(img,(64,64))

    img_small = np.expand_dims(img_small,0)

    probs = shape_model.predict(img_small,verbose=0)[0]

    return probs


# -----------------------------
# Blue gradient feature
# -----------------------------
def blue_gradient(img):

    blue = np.mean(img[:,:,2])

    return blue


# -----------------------------
# Feature extraction
# -----------------------------
def extract_features(img):

    shape_features = get_shape_percentage(img)

    blue = blue_gradient(img)

    feature_vector = np.append(shape_features, blue)

    return feature_vector


# -----------------------------
# Prediction function
# -----------------------------
def predict_thalassemia(image_path):

    img = preprocess_image(image_path)

    features = extract_features(img)

    img_input = np.expand_dims(img,0)

    feat_input = np.expand_dims(features,0)

    prediction = model.predict([img_input,feat_input])

    pred_class = np.argmax(prediction)

    if pred_class == 1:
        print("Prediction: Thalassemia Detected")
    else:
        print("Prediction: Healthy")

    print("Confidence:",prediction)


# -----------------------------
# Test with new image
# -----------------------------
predict_thalassemia("/content/drive/MyDrive/thalassemia_shape_based/tha1_test.png")
# Out:
# WARNING:tensorflow:6 out of the last 1003 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e7c0addbb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Prediction: Thalassemia Detected
# Confidence: [[3.5280186e-07 9.9999964e-01]]
